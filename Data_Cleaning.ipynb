# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({"studentid":list(range(1001,1010)),"age":[24,26,np.nan,"Ankita",15,18,"20",20.6,"19.4"]})
df
# Out:
#    studentid     age
# 0       1001      24
# 1       1002      26
# 2       1003     NaN
# 3       1004  Ankita
# 4       1005      15
# 5       1006      18
# 6       1007      20
# 7       1008    20.6
# 8       1009    19.4

# %%
df["age"].unique().tolist()
# Out:
# [24, 26, nan, 'Ankita', 15, 18, '20', 20.6, '19.4']

# %%
df.columns.tolist()
# Out:
# ['studentid', 'age']

# %%
#Observe the wrong data
l=[]
for i in  df["age"].unique().tolist():
    if type(i) not in [int,float]:
        l.append(i)
    
print(l)
# Out:
# ['Ankita', '20', '19.4']

# %%
# filter /select the wrong data
df[df["age"].isin(l)]
# Out:
#    studentid     age
# 3       1004  Ankita
# 6       1007      20
# 8       1009    19.4

# %% [markdown]
# ##### treat the wrong data

# %% [markdown]
# df.drop(index=df[df["age"].isin(l)].index.tolist())

# %% [markdown]
# ##### replace
#
# ##### 1. replace with original value by contacting backend team (best option)

# %%
# df.iloc[index] =new values
df.iloc[[3,6,8],1]=[25,26,27]

# %% [markdown]
# ##### 2. replace with statistical value (mean for numeric, mode for categorical)

# %%
df.iloc[[3,6,8],1]=df["age"].mean()

# %%
df
# Out:
#    studentid   age
# 0       1001    24
# 1       1002    26
# 2       1003   NaN
# 3       1004  22.7
# 4       1005    15
# 5       1006    18
# 6       1007  22.7
# 7       1008  20.6
# 8       1009  22.7

# %% [markdown]
# #### Duplicates

# %%
df = pd.DataFrame({"studentid":[101,102,102,103,104],"age":[24,27,27,28,29]})
df
# Out:
#    studentid  age
# 0        101   24
# 1        102   27
# 2        102   27
# 3        103   28
# 4        104   29

# %%
# observe the duplicates
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# filter the duplicates
df[df.duplicated()]
# Out:
#    studentid  age
# 2        102   27

# %%
# treat the duplicates()
df = df.drop_duplicates()

# %%
df
# Out:
#    studentid  age
# 0        101   24
# 1        102   27
# 3        103   28
# 4        104   29

# %%
df = pd.DataFrame({"studentid":[101,102,102,103,104],"age":[24,27,27,28,29]})
df
# Out:
#    studentid  age
# 0        101   24
# 1        102   27
# 2        102   27
# 3        103   28
# 4        104   29

# %%
df["studentid"].duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df["studentid"].duplicated()]
# Out:
#    studentid  age
# 2        102   27

# %%
df[df["studentid"]==102]
# Out:
#    studentid  age
# 1        102   27
# 2        102   27

# %%
df.drop(index=1)
# Out:
#    studentid  age
# 0        101   24
# 2        102   27
# 3        103   28
# 4        104   29

# %% [markdown]
# #### Missing Values

# %%
df = pd.DataFrame({"studentid":[101,102,np.nan,104,105],"age":[24,27,np.nan,28,np.nan]})
df
# Out:
#    studentid   age
# 0      101.0  24.0
# 1      102.0  27.0
# 2        NaN   NaN
# 3      104.0  28.0
# 4      105.0   NaN

# %%
# observe the missing values
df.isnull()
# Out:
#    studentid    age
# 0      False  False
# 1      False  False
# 2       True   True
# 3      False  False
# 4      False   True

# %%
# to observe no.of missing values in each column
df.isnull().sum()
# Out:
# studentid    1
# age          2
# dtype: int64

# %%
# to observe % of missinf values in each column
df.isnull().sum()/df.shape[0]*100
# Out:
# studentid    20.0
# age          40.0
# dtype: float64

# %%
# to observe no.of missing values in each row
df.isnull().sum(axis=1)
# Out:
# 0    0
# 1    0
# 2    2
# 3    0
# 4    1
# dtype: int64

# %%
# to observe % of missing values in each row
df.isnull().sum(axis=1)/df.shape[1]*100
# Out:
# 0      0.0
# 1      0.0
# 2    100.0
# 3      0.0
# 4     50.0
# dtype: float64

# %%
# filter/extract the missing values
df[df["age"].isnull()]
# Out:
#    studentid  age
# 2        NaN  NaN
# 4      105.0  NaN

# %% [markdown]
# #### treat missing values

# %% [markdown]
# #### 1.Drop/Remove the missing values

# %%
df.drop(index=df[df["age"].isnull()].index)
# Out:
#    studentid   age
# 0      101.0  24.0
# 1      102.0  27.0
# 3      104.0  28.0

# %%
df.dropna()
# Out:
#    studentid   age
# 0      101.0  24.0
# 1      102.0  27.0
# 3      104.0  28.0

# %%
df["age"] = df["age"].fillna(20)

# %%
df
# Out:
#    studentid   age
# 0      101.0  24.0
# 1      102.0  27.0
# 2        NaN  20.0
# 3      104.0  28.0
# 4      105.0  20.0

# %% [markdown]
# #### Unimportant columns

# %%
 # df = df.drop(columns=[ , , ,])

# %% [markdown]
# ##### Outliers

# %% [markdown]
# ##### how to observe the outliers

# %%
df = pd.DataFrame({"X":[1,26,5,10,15,20,18,14,19,24,30,36,22,27,100,150]})
df
# Out:
#       X
# 0     1
# 1    26
# 2     5
# 3    10
# 4    15
# 5    20
# 6    18
# 7    14
# 8    19
# 9    24
# 10   30
# 11   36
# 12   22
# 13   27
# 14  100
# 15  150

# %%
Q1 = df["X"].quantile(0.25)
Q3 =df["X"].quantile(0.75)

IQR=Q3-Q1

ll=Q1-(1.5*IQR)
print("lower limit:",ll)
ul=Q3+(1.5*IQR)
print("upper Limit:",ul)
# Out:
# lower limit: -4.75
# upper Limit: 47.25

# %%
df["X"].quantile([0,0.25,0.5,0.75,1])
# Out:
# 0.00      1.00
# 0.25     14.75
# 0.50     21.00
# 0.75     27.75
# 1.00    150.00
# Name: X, dtype: float64

# %% [markdown]
# ##### extract iutliers

# %%
df[(df["X"]<ll) | (df["X"]>ul)]
# Out:
#       X
# 14  100
# 15  150

# %%
df[(df["X"]<ll) | (df["X"]>ul)].shape[0]
# Out:
# 2
